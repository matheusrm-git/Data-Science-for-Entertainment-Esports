# %% [markdown]
# ### Demo instancing

# %%
import demo_analyzer as da
import importlib

importlib.reload(da)
# Out:
# <module 'demo_analyzer' from 'd:\\Git Repositories\\Data-Science-for-Entertainment-Esports\\Demo Analyzer\\demo_analyzer.py'>

# %%
path = "Furia Demos\\furia-vs-legacy-m3-mirage.dem"

analyzer = da.Analyzer(path)

# %% [markdown]
# ### Match Statistics

# %%
analyzer.map_stats_analysis(names=['FalleN', 'KSCERATO', 'yuurih', 'molodoy', 'YEKINDAR'])
# Out:
#      Player  Kills  Assists  Deaths   % HS  Flash Assists  K/D Ratio
# 1  KSCERATO     10        3       2  60.00              1       5.00
# 3   molodoy     17        0       7  23.53              0       2.43
# 2    yuurih     14        5       8  78.57              0       1.75
# 4  YEKINDAR     16        3      11  75.00              1       1.45
# 0    FalleN     11        3       8  27.27              0       1.38

# %% [markdown]
# ### Generating heatmap

# %%
analyzer.map_graph_analysis(names=["FalleN"],lower_limit=0,upper_limit=115,half=0,side='CT',heatmap=True, deaths=True,kills=True,bomb_plt=False)
# Out:
# Generating map image...
# Generating heatmap...
# Generating death marks...
# Generating kill marks...
